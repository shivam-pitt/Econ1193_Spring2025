# %%
import os
import json
import requests
import pandas as pd
from matplotlib import pyplot as plt

# %%
from usefulFunctions import BLS
# Out:
# Functions uploaded: readJSONfile, inflation, BLS

# %%
# %run "APIkeys.py"
key = os.environ['BLS_API_key']
# Out:
# API keys loaded now

# %%
BLS(key,display=True)

# %%
BLS(key,seriesDict={'CEU0500000003' : 'Private sector - AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES'},display=True)
